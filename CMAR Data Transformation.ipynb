# %%
# Import libraries
import pandas as pd
from sodapy import Socrata

# %%
client = Socrata("data.novascotia.ca", 'cx4XloH6tDgX8ZhFFmtAuxtMc')
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("eb3n-uxcb", limit=6000000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df
# Out:
#                waterbody        station lease  latitude  longitude  \
# 0        Country Harbour           1307  1307  45.16005  -61.68007
# 1        Country Harbour           1307  1307  45.16005  -61.68007
# 2        Country Harbour           1307  1307  45.16005  -61.68007
# 3        Country Harbour           1307  1307  45.16005  -61.68007
# 4        Country Harbour           1307  1307  45.16005  -61.68007
# ...                  ...            ...   ...       ...        ...
# 5476950   Chedabucto Bay  Tickle Island    NA   45.3594  -61.04287
# 5476951   Chedabucto Bay  Tickle Island    NA   45.3594  -61.04287
# 5476952   Chedabucto Bay  Tickle Island    NA   45.3594  -61.04287
# 5476953   Chedabucto Bay  Tickle Island    NA   45.3594  -61.04287
# 5476954   Chedabucto Bay  Tickle Island    NA   45.3594  -61.04287
#
#                   deployment_period                timestamp         sensor  \
# 0        2018-Dec-20 to 2019-Apr-02  2018-12-22T21:00:00.000  HOBO-10817410
# 1        2018-Dec-20 to 2019-Apr-02  2018-12-22T22:00:00.000  HOBO-10817410
# 2        2018-Dec-20 to 2019-Apr-02  2018-12-22T23:00:00.000  HOBO-10817410
# 3        2018-Dec-20 to 2019-Apr-02  2018-12-23T00:00:00.000  HOBO-10817410
# 4        2018-Dec-20 to 2019-Apr-02  2018-12-23T01:00:00.000  HOBO-10817410
# ...                             ...                      ...            ...
# 5476950  2020-Feb-24 to 2020-Oct-21  2020-10-21T08:00:00.000   VR2AR-547232
# 5476951  2020-Feb-24 to 2020-Oct-21  2020-10-21T09:00:00.000   VR2AR-547232
# 5476952  2020-Feb-24 to 2020-Oct-21  2020-10-21T10:00:00.000   VR2AR-547232
# 5476953  2020-Feb-24 to 2020-Oct-21  2020-10-21T11:00:00.000   VR2AR-547232
# 5476954  2020-Feb-24 to 2020-Oct-21  2020-10-21T12:00:00.000   VR2AR-547232
#
#         depth     variable  value
# 0           2  Temperature  3.036
# 1           2  Temperature  3.063
# 2           2  Temperature  3.116
# 3           2  Temperature  3.116
# 4           2  Temperature  3.168
# ...       ...          ...    ...
# 5476950    75  Temperature    3.2
# 5476951    75  Temperature    3.1
# 5476952    75  Temperature      3
# 5476953    75  Temperature      3
# 5476954    75  Temperature    7.2
#
# [5476955 rows x 11 columns]

# %%
subset_df = results_df.iloc[0:2000]
subset_df.loc[:, ('timestamp')] = pd.to_datetime(subset_df['timestamp'])
# typed_subset_df = subset_df.infer_objects()

# %%
grouped_df = subset_df.groupby(['waterbody', 'station', 'lease', 'latitude', 'longitude', 'deployment_period', 'timestamp', 'sensor', 'depth'])

# %%
def custom_agg_function(group):
    new_df = pd.DataFrame()
    print(dataframe['variable'])
    print(dataframe['value'])
    print('========*****=========')
    print(dataframe.dtypes)
    print('========*****=========')
    raise('stop')

# %%
grouped_df.apply(custom_agg_function)
# Out:
# 0    Temperature
# Name: variable, dtype: object
# 0    3.036
# Name: value, dtype: object
# ========*****=========
# waterbody                    object
# station                      object
# lease                        object
# latitude                     object
# longitude                    object
# deployment_period            object
# timestamp            datetime64[ns]
# sensor                       object
# depth                        object
# variable                     object
# value                        object
# dtype: object
# ========*****=========
# 0    Temperature
# Name: variable, dtype: object
# 0    3.036
# Name: value, dtype: object
# ========*****=========
# waterbody                    object
# station                      object
# lease                        object
# latitude                     object
# longitude                    object
# deployment_period            object
# timestamp            datetime64[ns]
# sensor                       object
# depth                        object
# variable                     object
# value                        object
# dtype: object
# ========*****=========
# 0    Temperature
# Name: variable, dtype: object
# 0    3.036
# Name: value, dtype: object
# ========*****=========
# variable    object
# value       object
# dtype: object
# ========*****=========
# 0    Temperature
# Name: variable, dtype: object
# 0    3.036
# Name: value, dtype: object
# ========*****=========
# variable    object
# value       object
# dtype: object
# ========*****=========
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/envs/CMAR/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     893             try:
# --> 894                 result = self._python_apply_general(f, self._selected_obj)
#     895             except TypeError:
#
# ~/miniconda3/envs/CMAR/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     927         """
# --> 928         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     929
#
# ~/miniconda3/envs/CMAR/lib/python3.9/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     237             group_axes = group.axes
# --> 238             res = f(group)
#     239             if not _is_indexed_like(res, group_axes, axis):
#
# <ipython-input-41-4605864b4429> in custom_agg_function(dataframe)
#       6     print('========*****=========')
# ----> 7     raise('stop')
#
# TypeError: exceptions must derive from BaseException
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-002650f45b0e> in <module>
# ----> 1 grouped_df.apply(custom_agg_function)
#
# ~/miniconda3/envs/CMAR/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     903
#     904                 with group_selection_context(self):
# --> 905                     return self._python_apply_general(f, self._selected_obj)
#     906
#     907         return result
#
# ~/miniconda3/envs/CMAR/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     926             data after applying f
#     927         """
# --> 928         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     929
#     930         return self._wrap_applied_output(
#
# ~/miniconda3/envs/CMAR/lib/python3.9/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     236             # group might be modified
#     237             group_axes = group.axes
# --> 238             res = f(group)
#     239             if not _is_indexed_like(res, group_axes, axis):
#     240                 mutated = True
#
# <ipython-input-41-4605864b4429> in custom_agg_function(dataframe)
#       5     print(dataframe.dtypes)
#       6     print('========*****=========')
# ----> 7     raise('stop')
#
# TypeError: exceptions must derive from BaseException
