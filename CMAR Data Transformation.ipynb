# %%
# Import libraries
import pandas as pd

# %%
df = pd.read_json('https://data.novascotia.ca/resource/eb3n-uxcb.json')

# %%
df
# Out:
#            waterbody  station  lease  latitude  longitude  \
# 0    Country Harbour     1307   1307  45.16005  -61.68007
# 1    Country Harbour     1307   1307  45.16005  -61.68007
# 2    Country Harbour     1307   1307  45.16005  -61.68007
# 3    Country Harbour     1307   1307  45.16005  -61.68007
# 4    Country Harbour     1307   1307  45.16005  -61.68007
# ..               ...      ...    ...       ...        ...
# 995  Country Harbour     1307   1307  45.16005  -61.68007
# 996  Country Harbour     1307   1307  45.16005  -61.68007
# 997  Country Harbour     1307   1307  45.16005  -61.68007
# 998  Country Harbour     1307   1307  45.16005  -61.68007
# 999  Country Harbour     1307   1307  45.16005  -61.68007
#
#               deployment_period           timestamp         sensor  depth  \
# 0    2018-Dec-20 to 2019-Apr-02 2018-12-22 21:00:00  HOBO-10817410      2
# 1    2018-Dec-20 to 2019-Apr-02 2018-12-22 22:00:00  HOBO-10817410      2
# ...
